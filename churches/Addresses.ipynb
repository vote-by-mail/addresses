# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import matplotlib
plt.style.use('ggplot')
matplotlib.rcParams['figure.figsize'] = 12, 6
matplotlib.rcParams['font.size'] = 18  # Probably OS Dependent

# %%
df = pd.read_json('../data/data.jl.gz', lines=True, compression='gzip')

# %%
df['state'] = df['address'].str.strip().str.split(' ').apply(lambda x: x[-1] if x else None)

# %%
series

# %%
series = df.groupby('state').size()
series[['WI', 'MI', 'VA', 'ME']].plot(kind='bar')
